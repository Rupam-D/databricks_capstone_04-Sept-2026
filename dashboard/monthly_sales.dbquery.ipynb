-- %%
select month_name, sum(net_amount) as monthly_sales from workspace.ibm.capstone_gold_sales group by month_name,month  order by month;
-- Out:
-- Databricks visualization. Run in Databricks to view.
