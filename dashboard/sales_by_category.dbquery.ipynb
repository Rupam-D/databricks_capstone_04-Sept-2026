-- %%
select category,sum(net_amount) as category_wise_sales from workspace.ibm.capstone_gold_sales group by category order by category;
-- Out:
-- Databricks visualization. Run in Databricks to view.
