# %%
# %sql
-- CHECK PERMISSION FOr VOLUME
show grants on volume workspace.ibm.databricks_capstone;

# %%
# %sql

-- GRANT CATALOG PERMISSION
GRANT USE CATALOG
ON CATALOG workspace
TO `acc49967-0f5a-4b97-b12b-fb9d6c999b8f`;

# %%
# %sql
-- grant read volume on volume workspace.ibm.databricks_capstone to `acc49967-0f5a-4b97-b12b-fb9d6c999b8f`;

-- GRANT SCHEMA PERMISSION
GRANT USE SCHEMA
ON SCHEMA workspace.ibm
TO `acc49967-0f5a-4b97-b12b-fb9d6c999b8f`;

# %%
# %sql
-- sHOW GRANTS ON CATALOG workspace;

-- SHOW GRANTS ON SCHEMA workspace.ibm;

-- SHOW GRANTS ON VOLUME workspace.ibm.databricks_capstone;

# %%
spark.sql("select current_user()").show(truncate=False)

# %%
# %sql
-- DESCRIBE EXTENDED workspace.ibm.capstone_bronze_sales;
GRANT ALL PRIVILEGES
ON SCHEMA workspace.ibm
TO `acc49967-0f5a-4b97-b12b-fb9d6c999b8f`;
